# %%
from trainer import Classifier
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot, plot_model
# Out:
# Using TensorFlow backend.

# %%
#構造の可視化
decoder = Classifier().decoder
SVG(model_to_dot(decoder,show_shapes=False,show_layer_names=False).create(prog="dot",format="svg"))
# Out:
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:134: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(256, 3, kernel_regularizer=<keras.reg..., strides=1, batch_input_shape=(None, 40,..., kernel_initializer="uniform", dilation_rate=1, activation="relu", padding="causal")`
#   batch_input_shape=batch_input_shape,init='uniform',kernel_regularizer=l2(0.00005)
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:143: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(256, 3, kernel_regularizer=<keras.reg..., strides=1, batch_input_shape=(None, 40,..., kernel_initializer="uniform", dilation_rate=1, activation="relu", padding="causal")`
#   batch_input_shape=batch_input_shape,init='uniform',kernel_regularizer=l2(0.00005)
# ...

# %%
plot_model(decoder,to_file='./model.png',show_layer_names=False)

# %%
pad_sequences([[1,2,3],[1,2,3,4,5]],4,padding='pre',truncating='post')
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 3, 4]], dtype=int32)

# %%
from keras.layers import Flatten, Lambda, TimeDistributed, Activation

# %%
from keras import backend as K

# %%
decoder.layers[0].layers[0].layers[0].layers[6].input

# %%
import numpy as np

# %%
tmp = np.array([[[1,2,3],[1,2,3],[1,2,3],[1,2,3]],[[0,1,2],[0,1,2],[0,1,2],[0,1,2]]])

# %%
np.array(list(zip(tmp[0],tmp[1])))
# Out:
# array([[[1, 2, 3],
#         [0, 1, 2]],
#
#        [[1, 2, 3],
#         [0, 1, 2]],
#
#        [[1, 2, 3],
#         [0, 1, 2]],
#
#        [[1, 2, 3],
#         [0, 1, 2]]])

# %%
tmp
# Out:
# array([[[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]],
#
#        [[0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2]]])
