# %%
from trainer import Classifier
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot, plot_model
# Out:
# Using TensorFlow backend.

# %%
#構造の可視化
decoder = Classifier().decoder
SVG(model_to_dot(decoder,show_shapes=True,show_layer_names=False).create(prog="dot",format="svg"))
# Out:
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:32: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(256, 2, batch_input_shape=(None, 40,..., padding="causal", strides=1, kernel_initializer="uniform", activation="relu", kernel_regularizer=<keras.reg...)`
#   batch_input_shape=batch_input_shape,init='uniform',kernel_regularizer=l2(0.00005))(inp)
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:40: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(256, 2, padding="causal", strides=1, dilation_rate=2, kernel_initializer="uniform", activation="relu", kernel_regularizer=<keras.reg...)`
#   init='uniform',kernel_regularizer=l2(0.00005))(conv)
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:48: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(256, 2, padding="causal", strides=1, dilation_rate=3, kernel_initializer="uniform", activation="relu", kernel_regularizer=<keras.reg...)`
#   init='uniform',kernel_regularizer=l2(0.00005))(conv2)
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:57: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("gl..., inputs=Tensor("in...)`
#   return Model(input=inp, output=out)
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:106: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   decoder.add(Merge([encoder_a, encoder_b], mode='concat'))
# /home/takayama/research/DBDC/annt_kmeans/trainer.py:112: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1024, kernel_initializer="uniform", activation="relu", kernel_regularizer=<keras.reg...)`
#   decoder.add(Dense(1024, activation='relu',kernel_regularizer=l2(0.00005),init='uniform'))

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
pad_sequences([[1,2,3],[1,2,3,4,5]],4,padding='pre',truncating='post')
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 3, 4]], dtype=int32)
