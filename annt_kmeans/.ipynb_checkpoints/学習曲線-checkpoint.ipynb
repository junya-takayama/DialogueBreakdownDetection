# %%
import pickle
from matplotlib import pyplot as plt

# %%
def visualize(fp):
    data = pickle.load(open(fp,"rb"))
    print("cluster number:",data["numOfClusters"])
    print("accuracy",data["accuracy"])
    for i,history in enumerate(data["history"]):
        x = list(range(1,len(history["loss"])+1))
        plt.figure()
        plt.xlabel("number of epoch")
        plt.ylabel("value of loss / mse")
        plt.title("learning curve of cluster "+str(i))
        for label,value in history.items():
            if label == "lr":
                continue
            plt.plot(x[:100], value[:100], label=label)
        #plt.plot(x, history['val_loss'], label='val_loss')
        #plt.plot(x, history['val_mean_squared_error'], label='val_mean_squared_error')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.show()

# %%
visualize("./models/test1.pickle")
# Out:
# cluster number: 1
# accuracy 0.6754545454545454

# %%
visualize("./models/test2.pickle")
# Out:
# cluster number: 2
# accuracy 0.6627272727272727

# %%
visualize("./models/test3.pickle")
# Out:
# cluster number: 3
# accuracy 0.6709090909090909

# %%
visualize("./models/test4.pickle")
# Out:
# cluster number: 4
# accuracy 0.6890909090909091

# %%
visualize("./models/test5.pickle")
# Out:
# cluster number: 5
# accuracy 0.6809090909090909

# %%
visualize("./models/test6.pickle")
# Out:
# cluster number: 6
# accuracy 0.6627272727272727

# %%
visualize("./models/test7.pickle")
# Out:
# cluster number: 7
# accuracy 0.6936363636363636

# %%
visualize("./models/test8.pickle")
# Out:
# cluster number: 8
# accuracy 0.6745454545454546

# %%
visualize("./models/test9.pickle")
# Out:
# cluster number: 9
# accuracy 0.6781818181818182

# %%
visualize("./models/test10.pickle")
# Out:
# cluster number: 10
# accuracy 0.6881818181818182
