# %%
from BDkeras import Classifier
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot, plot_model
# Out:
# Using TensorFlow backend.

# %%
#構造の可視化
decoder = Classifier().decoder
SVG(model_to_dot(decoder,show_shapes=True,show_layer_names=False).create(prog="dot",format="svg"))
# Out:
# /home/takayama/research/DBDC/BDkeras.py:28: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(batch_input_shape=(None, 30,..., recurrent_dropout=0.6, return_sequences=False, units=200)`
#   encoder_a.add(GRU(output_dim=wvdim, batch_input_shape=(None, pad_size, wvdim), return_sequences=False,dropout_U=0.6))
# /home/takayama/research/DBDC/BDkeras.py:32: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(batch_input_shape=(None, 30,..., recurrent_dropout=0.6, return_sequences=False, units=200)`
#   encoder_b.add(GRU(output_dim=wvdim, batch_input_shape=(None, pad_size, wvdim), return_sequences=False,dropout_U=0.6))
# /home/takayama/research/DBDC/BDkeras.py:36: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   decoder.add(Merge([encoder_a, encoder_b], mode='concat'))
